# %%
# 67. Add Binary
'''
Given two binary strings a and b, return their sum as a binary string.

 

Example 1:

Input: a = "11", b = "1"
Output: "100"

Example 2:

Input: a = "1010", b = "1011"
Output: "10101"
'''

# %%
def addBinary(a,b):
    
    print(a, len(a))
    print(b, len(b))
    r = ""
    ans = ""
    temp = ""
    carry = "0"
    al = len(a)
    bl = len(b)
    i = ""
    j = ""

    if al>=bl:
        size = al
        temp = "0" * (size - bl)
        b = temp + b
    else:
        size = bl
        temp = "0" * (size - al)
        a = temp + a
        
        
    print(a)
    print(b)
    print("============")
        
        
    for x in range(size-1,-1,-1):
        print(x)
        
        i = a[x]
        j = b[x]
            
        print(i,j,carry)
        print(type(i),type(j),type(carry))
        
        if i == "1" and j == "1" and carry == "1":
            print("111")
            r = "1"
            carry = "1"
        elif i == "1" and j == "1" and carry == "0":
            print("110")
            r = "0"
            carry = "1"
        elif i == "0" and j == "1" and carry == "1":
            print("011")
            r = "0"
            carry = "1"
        elif i == "1" and j == "0" and carry == "1":
            print("101")
            r = "0"
            carry = "1"
        elif i == "0" and j == "1" and carry == "0":
            print("010")
            r = "1"
            carry = "0"
        elif i == "1" and j == "0" and carry == "0":
            print("100")
            r = "1"
            carry = "0"
        elif i == "0" and j == "0" and carry == "1":
            print("001")
            r = "1"
            carry = "0"
        elif i == "0" and j == "0" and carry == "0":
            print("000")
            r = "0"
            carry = "0"
        print(r)
        print("========")
        print(ans)
        ans = ans + r
        print(ans)
    
    if carry == "1":
        print(ans)
        print("here")
        
        ans+="1"
        print(ans)
    
    
    return ans[::-1]

#a = "11"
#b = "1"

a = "1010"
b = "1011"

a = "1"
b = "111"

a = "100"
b = "110010"

addBinary(a,b)
# Out:
# 100 3
# 110010 6
# 000100
# 110010
# ...
# 5
# 0 0 0
# <class 'str'> <class 'str'> <class 'str'>
# 000
# 0
# ...
#
# 0
# 4
# 0 1 0
# <class 'str'> <class 'str'> <class 'str'>
# 010
# 1
# ...
# 0
# 01
# 3
# 1 0 0
# <class 'str'> <class 'str'> <class 'str'>
# 100
# 1
# ...
# 01
# 011
# 2
# 0 0 0
# <class 'str'> <class 'str'> <class 'str'>
# 000
# 0
# ...
# 011
# 0110
# 1
# 0 1 0
# <class 'str'> <class 'str'> <class 'str'>
# 010
# 1
# ...
# 0110
# 01101
# 0
# 0 1 0
# <class 'str'> <class 'str'> <class 'str'>
# 010
# 1
# ...
# 01101
# 011011
# '110110'
